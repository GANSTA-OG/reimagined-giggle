# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# <strong>OJASWI </strong> <br>
# AR/VR ENGINEER

# %% [markdown]
# *I am interested in data science as it is one of the fastest growing IT domains of the 21<sup>st</sup> Century. Data science has wide applications in all fields of the economy and everyday life making it even more intriguing and important to study*

# %% [markdown]
# <h3> This is a really simple code that performs the given mathematical problem using the principle of BODMAS/PEMDAS and displays cool </h3>

# %%
print("20*20-40/10+(10*10)+10=")
print(20*20-40/10+(10*10)+10)
print("cool")
# Out:
# 20*20-40/10+(10*10)+10=
# 506.0
# cool

# %% [markdown]
# <hr>
# This an an bullet list.
# <ul> <li> Item 1 </li> <li> Item 2 </li> <li> Item 2</li> </ul>
#
#
# <hr>
# This an an numbered list.
# <ol> <li> Item 1 </li> <li> Item 2 </li> <li> Item 2</li> </ol>
#
#
# <hr>
# This is a table
# <table> <tr>
#             <th> A</th>
#             <th> B</th>
#         </tr>
#         <tr>
#             <td> 1</td>
#             <td>2 </td>
#         </tr>
#         <tr>
#             <td> 1</td>
#             <td>2 </td>
#         </tr>
# </table>
#
#
# <hr>
# This is a hyperlink to
# <a href ="https://www.google.co.in/">GOOGLE</a>
#
#
# <hr>
# This is an image
# ![image.png](attachment:be3d8c27-8551-4704-9d6f-c38a65848713.png)!
#
#
# <hr>
